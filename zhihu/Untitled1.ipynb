# %%
#encoding:utf-8
import urllib2
from bs4 import BeautifulSoup
import re
import requests
# import redis
from lxml import html
import pandas as pd
import csv
import os
from bs4 import BeautifulSoup
import urllib2
import numpy as np
from multiprocessing import Pool
from multiprocessing.dummy  import Pool
# user_agent = 'Mozilla/4.0 (compatible; MSIE 5.5; Windows NT)'
# values = {'username' : 'cqc',  'password' : 'XXXX' }
headers = {   'User-Agent': "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36"}
p=re.compile(r'urlToken":"(.*?)",')
num=re.compile('\d+')
import random
def proxys():
    proxy_cont=open("proxy_avi.txt")
    proxy_list=proxy_cont.read().split('\n')
    proxy_cont.close()
    return proxy_list

def  opener(url,proxy):
    User_Agent = 'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:43.0) Gecko/20100101 Firefox/43.0'
    header = {}
    header['User-Agent'] = User_Agent
    proxy_support = urllib2.ProxyHandler(proxy)  # 注册代理
    # opener = urllib2.build_opener(proxy_support,urllib2.HTTPHandler(debuglevel=1))
    opener = urllib2.build_opener(proxy_support)
    urllib2.install_opener(opener)
    req = urllib2.Request(url,headers=header)
    response=urllib2.urlopen(req,None).read()
    return response

def get_user_info(name=None):
    try:
        url='https://www.zhihu.com/people/'+name+'/following'
        req=urllib2.Request(url, headers=headers)
        p=np.random.randint(1,69143)
        pox=proxyPool[p]
        proxy={"http":pox.split('\t')[0]}
        req=opener(url=url,proxy=proxy)
        # print urllib2.urlopen(req).read()
        soup = BeautifulSoup(req)
        t1=soup.find('ul',class_='Tabs ProfileMain-tabs').text
        t2=soup.find('div',class_='Profile-sideColumnItem').text
        t3=soup.find('div',class_='NumberBoard FollowshipCard-counts').text
        t4=soup.find('div',class_='Profile-lightList').text
#         file_path='user_data/'+name[0]+'.csv'
        tt=t1+t2+t3+t4
        info=num.findall(tt)
        global n
        n+=1
        print '-------%d----%s---'%(n,name)
        pd.DataFrame(info,columns=[name]).T.to_csv('user_data/'+name[0]+'.csv',header=False,mode='a+b')
    except  Exception as e:
        info=None
        print e
        pd.DataFrame(info,columns=[name]).T.to_csv('uncrawler_info/'+name[0]+'.csv',header=False,mode='a+b')

# %%
if __name__=="__main__":
    n=0
    proxyPool=proxys()
    tokens=pd.read_csv('tokens.csv',index_col=0).values.flatten()
    pool = Pool(8)
    pool.map(get_user_info,tokens)
    pool.close()
    pool.join()

# %%
import numpy as np

# %%
import os
from bs4 import BeautifulSoup
import urllib2
from multiprocessing import Pool
import random
def proxys():
    proxy_cont=open("proxy_avi.txt")
    proxy_list=proxy_cont.read().split('\n')
    proxy_cont.close()
    return proxy_list

def  opener(url,proxy):
    User_Agent = 'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:43.0) Gecko/20100101 Firefox/43.0'
    header = {}
    header['User-Agent'] = User_Agent
    proxy_support = urllib2.ProxyHandler(proxy)  # 注册代理
    # opener = urllib2.build_opener(proxy_support,urllib2.HTTPHandler(debuglevel=1))
    opener = urllib2.build_opener(proxy_support)
    urllib2.install_opener(opener)
    req = urllib2.Request(url,headers=header)
    response=urllib2.urlopen(req,None)
    return response


if __name__=='__main__':

# %%
import pandas as pd
import os

# %%
files=[os.path.join('user_data/',line)  for line in os.listdir('user_data/')]

# %%
dd=pd.read_csv(files[0],index_col=0)
for line in files[1:]:
    temp=pd.read_csv(line,index_col=0)
    pd.concat([dd,temp],axis=1)
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-10-2ffb108c411f> in <module>()
#       1 dd=pd.read_csv(files[0],index_col=0)
#       2 for line in files[1:]:
# ----> 3     temp=pd.read_csv(line,index_col=0)
#       4     pd.concat([dd,temp],axis=1)
#
# ...

# %%
gg=open('tt.csv','a+b')
for line in files:
    with open(line) as f:
        for l  in f.readlines():
            if len(l)>30:
                gg.write(l)
gg.close()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-25-6380bd439e25> in <module>()
#       1 gg=open('tt.csv','a+b')
#       2 for line in files:
# ----> 3     with open(line) as f:
#       4         for l  in f.readlines():
#       5             if len(l)>30:
#
# IOError: [Errno 21] Is a directory: 'user_data/.ipynb_checkpoints'

# %%
dd=pd.read_csv('tt.csv',index_col=0)

# %%
dd
# Out:
#                     14      1     5     8      16       4     5.1      62  \
# ZJsnowman
# Zampeli           10.0    5.0  87.0  46.0  6875.0    79.0  1346.0  1066.0
# ZhangAW           59.0    0.0   1.0   7.0  1182.0   229.0   171.0   212.0
# Ziloon            21.0    0.0   1.0   3.0   251.0    41.0    23.0    61.0
# Zhibow             1.0    0.0   1.0   2.0     2.0    42.0     7.0    13.0
# Z-XD             480.0    0.0  18.0  21.0   471.0   103.0    29.0    45.0
# Zllin1994          5.0    0.0   2.0   1.0     5.0     1.0    78.0     8.0
# Zaffre            27.0    2.0   6.0   0.0   398.0   132.0   263.0   286.0
# Z-T-T              8.0    0.0   0.0   1.0   176.0    14.0     9.0    35.0
# Zainzhang          0.0    0.0   2.0   0.0     5.0    80.0    37.0    16.0
# Zealer1258         1.0    0.0   1.0   0.0     2.0    20.0     1.0     1.0
# ZsmsT              0.0    0.0   3.0   5.0     4.0    44.0     2.0    10.0
# ...
