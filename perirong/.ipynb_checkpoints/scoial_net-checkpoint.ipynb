# %%
sqlContext.sql("show databases").show()
# Out:
# +--------------------+
# |              result|
# +--------------------+
# |                 adl|
# |      antifraud_data|
# |                 app|
# |                 bak|
# |             crawler|
# |       crawler_hbase|
# |          data_basic|
# | data_crawler_market|
# |       data_snowball|
# |             default|
# |                 dim|
# |                dsst|
# |                 fdl|
# |                 gdl|
# |       risk_analysis|
# |     risk_anti_fraud|
# |risk_crawler_anal...|
# |           risk_oper|
# |                test|
# |                 tmp|
# +--------------------+

# %%
calls=sqlContext.sql("select * from crawler.app_call_record_hive limit 1000")
calls.show()
# Out:
# +--------------------+----------+-----+-----------+-------------------+----+-------------------+-------+-----------+----+--------------+----------+
# |              rowkey|custorm_id| name|     number|          call_time|type|        create_time|name_cb|  number_cb|time|  call_time_cb|        dt|
# +--------------------+----------+-----+-----------+-------------------+----+-------------------+-------+-----------+----+--------------+----------+
# |0000162_352270791...|   2610000| null|15023615259|2016-10-24 14:54:42|   1|2016-10-24 16:13:53|   null|15023615259|  24|20161024145442|2016-10-24|
# |0000162_352270821...|   2610000| null|15998912551|2016-10-24 14:49:47|   2|2016-10-24 16:13:53|   null|15998912551| 147|20161024144947|2016-10-24|
# |0000162_352270908...|   2610000|   蔡哥|15213108100|2016-10-24 14:35:17|   1|2016-10-24 16:13:53|     蔡哥|15213108100| 146|20161024143517|2016-10-24|
# ...
