# %%
import  pandas as pd
data=pd.read_csv("crawler_mobi_call_record_hive.csv")

# %%
data.head(10)
# Out:
#         number  call_time_sum_0812  call_time_cnt_1821  var_call_time_lag  \
# 0  13001517056                2734                  25       11791.564687
# 1  13002131456                4243                  29        6286.867394
# 2  13003360256               11038                 115       11035.752958
# 3  13004998656               19229                 277        9861.833299
# 4  13005817856                 504                  10       11590.501275
# 5  13006432256                6025                  39       15187.817063
# 6  13007251456               16364                 208        7921.898954
# 7  13007661056               33490                 203       12738.909571
# 8  13007865856               19427                 150        8370.735707
# 9  13009709056                7978                  63        6472.755821
#
#    kurt_call_time_lag  call_time_stddev_pop_0107  call_time_cnt_0812  \
# 0            0.095679                  13.242356                  50
# ...

# %%
data.columns
# Out:
# Index([u'number', u'call_time_sum_0812', u'call_time_cnt_1821',
#        u'var_call_time_lag', u'kurt_call_time_lag',
#        u'call_time_stddev_pop_0107', u'call_time_cnt_0812',
#        u'avg_call_time_lag', u'call_time_avg_2200', u'longest_call_time_lag',
#        u'avg_everyday_call_time', u'avg_time', u'call_time_cnt_1317',
#        u'freq_num', u'std_time', u'call_time_max_1317', u'shortest_time',
#        u'call_time_max_1821', u'call_time_sum_2200', u'sum_time',
#        u'shortest_call_time_lag', u'longest_time', u'call_time_sum_0107',
#        u'call_time_sum_1821', u'call_time_max_0812', u'std_time_lag',
#        u'var_time', u'call_time_avg_1821', u'std_call_time_lag',
#        u'call_time_stddev_pop_1317', u'call_time_avg_0107',
#        u'call_time_avg_1317', u'sum_call_time_lag', u'kurt_time',
#        u'call_time_stddev_pop_2200', u'call_time_stddev_pop_1821',
#        u'call_time_max_0107', u'call_time_avg_0812', u'cust_num',
# ...
